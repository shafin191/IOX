# %%
import random
import datetime
import os
import twikit
from twikit import Client
import json
import pandas as pd
import time
import pickle
import asyncio
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 50)

# %%
pwd
# Out:
# '/a/bear.cs.fiu.edu./disk/bear-b/users/ashaf016/IO-USA'

# %%
client = Client('en-US')
#client.login(auth_info_1='fiucasprlab@gmail.com', password='CasprLab225699')
#client.save_cookies('cookies1.json')
#client.login(auth_info_1='fiucasprlab@gmail.com', password='CasprLab225699')
#client.save_cookies('cookies.json')
#client.load_cookies(path='cookie_caspr.json')
client.load_cookies(path='cookie_new.json')
#client.load_cookies(path='cookie_JohnFisher.json')

# %%
twikit.__version__
# Out:
# '2.1.3'

# %%
#pip install pandas

# %%
#pip install numpy

# %%
now = datetime.datetime.now()
current_date = now.date()

newpath = "/a/bear.cs.fiu.edu./disk/bear-b/users/ashaf016/IO-USA/" +  str(current_date) + "/"
if not os.path.exists(newpath):
    os.makedirs(newpath)

# %%
tweets = await client.get_user_tweets(user_id = 51728851,tweet_type ='Tweets')

# %%
tweets
# Out:
# [<Tweet id="1842202884907429931">, <Tweet id="1842202839650820203">, <Tweet id="1842202640962540024">, <Tweet id="1841689788124127721">, <Tweet id="1841677684973437237">, <Tweet id="1841677565846815182">, <Tweet id="1841677156872765614">, <Tweet id="1841677046784864373">, <Tweet id="1841206595453141384">, <Tweet id="1841206475135598845">, <Tweet id="1841187942594986263">, <Tweet id="1841029881972572294">, <Tweet id="1841009306373931477">, <Tweet id="1841008755368215015">, <Tweet id="1840239813494223309">, <Tweet id="1839897197238010051">, <Tweet id="1839883332206879219">, <Tweet id="1839874717303615603">, <Tweet id="1839871766614995293">, <Tweet id="1839871728882987479">]

# %%
client.get_user_tweets(user_id = 51728851,tweet_type ='Tweets')
# Out:
# <coroutine object Client.get_user_tweets at 0x7f7099bc9120>

# %%
with open("/a/bear.cs.fiu.edu./disk/bear-b/users/ashaf016/IO-USA//Daily_List_2", "r") as fp:
    my_list = json.load(fp)

# %%
my_list
# Out:
# ['1663308107240570880',
#  '1663360110645874690',
#  '1663701168839872512',
#  '1667139440760995842',
#  '1669394751689293825',
#  '1672163912018546691',
#  '1673687943993606147',
#  '1674083297486417921',
#  '1674591149892284424',
#  '1674861136498286605',
#  '1675166085279019009',
#  '1677233187032911872',
#  '1678841863296491606',
#  '1679273889648594944',
#  '1679637730215489541',
#  '1680741393172672514',
#  '1682389805882122240',
#  '1683021082356510722',
#  '1683658959670984704',
#  '1684600836620705792',
#  '1685660003753971712',
#  '1685770941807149056',
#  '1686093224983814144',
#  '1686542365807239168',
#  '1686901686185721857',
#  '1688817352681689088',
#  '1690420926293114880',
#  '1690434051465719808',
#  '1690766743352791040',
#  '1691831673044824064',
#  '1692485547359453184',
#  '1692949282557444096',
#  '1693966480117846016',
#  '1694130567770501121',
#  '1694635657115901952',
#  '1695181896236359680',
#  '1695534402665615360',
#  '1695918548504449024',
#  '1696475455682158592',
#  '1698762197042966528',
#  '1702919782633480192',
#  '1704277567170375680',
#  '1705001442300293120',
#  '1705676719569420288',
#  '1709051928666091520',
#  '1710677339556974592',
#  '1148407950',
#  '1518700962852085760',
#  '249666995',
#  '445183185',
#  '524869533',
#  '1028540906037764096',
#  '39692424',
#  '1595537956751740928',
#  '819994707061248001',
#  '132339474',
#  '1464847548535955460',
#  '874906266736484352',
#  '920065260324827137',
#  '1551337225895530497',
#  '1544919640954085377',
#  '1535722790837534723',
#  '807355480188141568',
#  '4248352301',
#  '497088625',
#  '1121807798826930177',
#  '1515139948910891016',
#  '1329171068196622337',
#  '51728851',
#  '3039785666',
#  '1496479280716558343',
#  '37754557',
#  '399178595',
#  '1412196388796960776',
#  '1549183329206996992',
#  '1518719815640395777',
#  '1087380412089987077',
#  '1537225604554031104',
#  '1259862054',
#  '1540801222772494336',
#  '701725963',
#  '3419210573',
#  '1270133776748855304',
#  '1145494391169191937',
#  '1109532876310302721',
#  '1569114924047122432',
#  '1430824238261235716',
#  '2234760798',
#  '861558751152754689',
#  '15137097',
#  '1288319695658135552',
#  '1607214086139387904',
#  '1213874306515554306',
#  '69156861',
#  '708236539353030656',
#  '65494780',
#  '288277167',
#  '17469289',
#  '573239329',
#  '1590428702353096707',
#  '1233044852675416065',
#  '902763472555044865',
#  '1492672330207797254',
#  '1550207950026833921',
#  '8383592',
#  '2256965582',
#  '1635369805724221441',
#  '1483750637275860993',
#  '450235955',
#  '18093097',
#  '1537291933495615488',
#  '339241927',
#  '1591076408817848320',
#  '425625674',
#  '792660210',
#  '1755332987732787200',
#  '1548804262125355010',
#  '18929234',
#  ...]

# %%
tweets = await client.get_user_tweets(user_id = my_list[0],tweet_type ='Tweets')

# %%
tweets
# Out:
# [<Tweet id="1842304841647087631">, <Tweet id="1842301926265991463">, <Tweet id="1842281194710569399">, <Tweet id="1841615286358757697">, <Tweet id="1841610052240654834">, <Tweet id="1841579795160957316">, <Tweet id="1841569579723534427">, <Tweet id="1841540269520355589">, <Tweet id="1841299167190057213">, <Tweet id="1841290282911830211">, <Tweet id="1840770975769436553">, <Tweet id="1839659808665809022">, <Tweet id="1839468110136713250">, <Tweet id="1839063327500284093">, <Tweet id="1838668230292050245">]

# %%
import asyncio
import os
import twikit
import random
import datetime
import pickle
import time
import pandas as pd
import sys

# No need to write "from twikit.twikit_async import Client"
from twikit import Client

#client = Client()

async def main() -> None:
    now = datetime.datetime.now()
    current_date = now.date()
    client = Client("en-US")
    print(twikit.__version__)
    client.load_cookies('cookie_JohnFisher.json')
    my_list = []
    
    with open("/a/bear.cs.fiu.edu./disk/bear-b/users/ashaf016/IO-USA//Daily_List_2", "r") as fp:
        my_list = json.load(fp)
        
    newpath = "/a/bear.cs.fiu.edu./disk/bear-b/users/ashaf016/IO-USA/" +  str(current_date) + "/"
    #newpath = "/home/mnemo/users/ashaf016/USA Influence Opearations/Monitor Daily Account/2024-09-27_2/"
    if not os.path.exists(newpath):
        os.makedirs(newpath)
        
    df_group_list =my_list
    check_num = 0
    user_prob2 = []
    
    for k in df_group_list:
        check_num = check_num + 1
       
        try:
            tweets = await client.get_user_tweets(user_id = k,tweet_type ='Tweets')
            #user_following3 = clientget_user_following(k)
           
        except:
            print(str(k) + ' was a problem.')
            user_prob2.append(k)
            time.sleep(30)
            continue
        
        tweets_to_store = []
        for tweet in tweets:
            if tweet.text[0:4] == 'RT @':
                #print('This is a Retweet')
                try:
                    tweets_to_store.append({
                        'User_ID': tweet.user.id,
                        'Tweet_ID': tweet.id,
                        'Retweet_ID': tweet.retweeted_tweet.id,
                        'Retweet_User_ID': tweet.retweeted_tweet.user.id,
                        'created_at': tweet.created_at,
                        'Retweet_created_at':tweet.retweeted_tweet.created_at,
                        'favorite_count': tweet.favorite_count,
                        'retweet_count': tweet.retweet_count,
                        'media':tweet.media,
                        'Retweet_Media': tweet.retweeted_tweet.media,
                        'text': tweet.text,
                        'Retweet_Text': tweet.retweeted_tweet.text,
                        'full_text': tweet.full_text,
                        'Text_Lang': tweet.lang,
                        'Retweet_Lang':tweet.retweeted_tweet.lang,
                        'View_Count': tweet.view_count,
                        'Comment_Count':tweet.reply_count,
                        'Quote_Count': tweet.quote_count,
                        'Text_Hashtags':tweet.hashtags,
                        'has_community_note': tweet.has_community_notes, 
                        'Link': tweet.urls,       
                        'Data_Collection_Time': datetime.datetime.now()
                
                    })
                except:
                    tweets_to_store.append({
                        'User_ID': tweet.user.id,
                        'Tweet_ID': tweet.id,
                        'created_at': tweet.created_at,
                        'favorite_count': tweet.favorite_count,
                        'retweet_count': tweet.retweet_count,
                        'media':tweet.media,
                        'text': tweet.text,
                        'full_text': tweet.full_text,
                        'Text_Lang': tweet.lang,
                        'View_Count': tweet.view_count,
                        'Comment_Count':tweet.reply_count,
                        'Quote_Count': tweet.quote_count,
                        'Text_Hashtags':tweet.hashtags,
                        'has_community_note': tweet.has_community_notes, 
                        'Link': tweet.urls,       
                        'Data_Collection_Time': datetime.datetime.now()})
            else:
                #print('This is a Tweet')
                tweets_to_store.append({
                    'User_ID': tweet.user.id,
                    'Tweet_ID': tweet.id,
                    'created_at': tweet.created_at,
                    'favorite_count': tweet.favorite_count,
                    'retweet_count': tweet.retweet_count,
                    'media':tweet.media,
                    'text': tweet.text,
                    'full_text': tweet.full_text,
                    'Text_Lang': tweet.lang,
                    'View_Count': tweet.view_count,
                    'Comment_Count':tweet.reply_count,
                    'Quote_Count': tweet.quote_count,
                    'Text_Hashtags':tweet.hashtags,
                    'has_community_note': tweet.has_community_notes, 
                    'Link': tweet.urls,       
                    'Data_Collection_Time': datetime.datetime.now()})
        #print(tweets)
        with open(newpath + "Tweet_"+ str(k)+ "_" + str(check_num) +".pkl", "wb") as f:
            pickle.dump(tweets_to_store, f)
        try:
            df_tweet = pd.DataFrame(tweets_to_store)
            df_tweet.to_csv(newpath +str(k) +"_" + str(check_num) +"_Tweets.csv", index = False)
        #df_user.to_csv('V:/SBERT All Embedding/Following_List/' +str(k) +'_Following.csv')
        except:
            print('Problem')

        time.sleep(30)
        #break
        if check_num%100 == 0:
            time.sleep(20)
        break


    print("Program Execution Complete")
    print("Total_Problem: " + str(len(user_prob2)))
    

asyncio.run(main())
sys.exit()

# %%
#asyncio.run(main())
#sys.exit()
